# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
###################################################################
# Plot options
###################################################################

font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15,7)

###################################################################
# Colors
###################################################################
# Palette 1
#tableau20 = [(82, 96, 131), (174, 199, 232), (225, 134, 40), (255, 187, 120),
#             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),
#             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),
#             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),
#             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]
# Palette 1
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]
for i in range(len(tableau20)):
    r, g, b = tableau20[i]
    tableau20[i] = (r / 255., g / 255., b / 255.)
MarkerSize=20
palette=tableau20

import matplotlib
matplotlib.colors.ColorConverter.colors['palette1'] = palette[0]
matplotlib.colors.ColorConverter.colors['palette2'] = palette[2]
matplotlib.colors.ColorConverter.colors['palette3'] = palette[4]
matplotlib.colors.ColorConverter.colors['palette4'] = palette[6]
matplotlib.colors.ColorConverter.colors['palette5'] = palette[8]
matplotlib.colors.ColorConverter.colors['palette6'] = palette[10]
matplotlib.colors.ColorConverter.colors['palette7'] = palette[12]
matplotlib.colors.ColorConverter.colors['palette8'] = palette[14]
matplotlib.colors.ColorConverter.colors['palette9'] = palette[16]
matplotlib.colors.ColorConverter.colors['palette10'] = palette[18]

paletteNames=['palette1','palette2','palette3','palette4',
              'palette5','palette6','palette7','palette8',
              'palette9','palette10']

def hex_to_rgb(value):
    value = value.lstrip('#')
    lv = len(value)
    rgb=tuple(int(value[i:i + lv // 3], 16) for i in range(0, lv, lv // 3))
    return tuple([x/255. for x in rgb])

from matplotlib.colors import LinearSegmentedColormap

my_colormap=LinearSegmentedColormap.from_list("my_colormap", [palette[0],hex_to_rgb("#ffffff"), palette[2] ], N=1000)


cm_blue3 = LinearSegmentedColormap.from_list("my_blue3", [hex_to_rgb("#FFFFFF"),palette[0]], N=1000)
cm_orange3 = LinearSegmentedColormap.from_list("my_orange3", [hex_to_rgb("#FFFFFF"),palette[2]], N=1000)

###################################################################
# Fessa palette for python matplotlib
###################################################################
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

def hex_to_rgb(value):
    value = value.lstrip('#')
    lv = len(value)
    rgb=tuple(int(value[i:i + lv // 3], 16) for i in range(0, lv, lv // 3))
    return tuple([x/255. for x in rgb])


paletteFessa = [
          hex_to_rgb("#1F3B73"),
          hex_to_rgb("#2F9294"),
          hex_to_rgb("#50B28D"),
          hex_to_rgb("#A7D655"),
          hex_to_rgb("#FFE03E"),
          hex_to_rgb("#FFA955"),
          hex_to_rgb("#D6573B")
         ]

cm_fessa = LinearSegmentedColormap.from_list("fessa", paletteFessa, N=1000)

matplotlib.colors.ColorConverter.colors['fessa1'] = paletteFessa[0]
matplotlib.colors.ColorConverter.colors['fessa2'] = paletteFessa[1]
matplotlib.colors.ColorConverter.colors['fessa3'] = paletteFessa[2]
matplotlib.colors.ColorConverter.colors['fessa4'] = paletteFessa[3]
matplotlib.colors.ColorConverter.colors['fessa5'] = paletteFessa[4]
matplotlib.colors.ColorConverter.colors['fessa6'] = paletteFessa[5]
matplotlib.colors.ColorConverter.colors['fessa7'] = paletteFessa[6]

fessaNames=['fessa1', 'fessa2' , 'fessa3', 'fessa4', 
              'fessa5', 'fessa6' , 'fessa7']

cm_fessa2 = LinearSegmentedColormap.from_list("fessa", [paletteFessa[1],hex_to_rgb("#ffffff"),paletteFessa[5]], N=1000)

# %%
freeEnergy0bar=np.genfromtxt("/mnt/storage3/piaggp/PhaseDiagramsFromSingleSimulations/Sodium/UseRefCV/Bias/Multithermal-Multibaric/Test4/ReweightConstPressure/freeEnergies-0bar.txt")
freeEnergy10000bar=np.genfromtxt("/mnt/storage3/piaggp/PhaseDiagramsFromSingleSimulations/Sodium/UseRefCV/Bias/Multithermal-Multibaric/Test4/ReweightConstPressure/freeEnergies-10000bar.txt")
references0bar=np.genfromtxt("/mnt/storage3/piaggp/PhaseDiagramsFromSingleSimulations/Sodium/UseRefCV/References/Pressure1/results.txt")
references10000bar=np.genfromtxt("/mnt/storage3/piaggp/PhaseDiagramsFromSingleSimulations/Sodium/UseRefCV/References/Pressure10000/results.txt")

# %%
plt.plot(np.linspace(340,460,2),0.*np.linspace(340,460,2),'--',color='black',alpha=0.5)

plt.plot(freeEnergy0bar[:,0],freeEnergy0bar[:,2]+freeEnergy0bar[:,4],color=palette[0],linewidth=1.)
plt.plot(freeEnergy0bar[:,0],freeEnergy0bar[:,2]-freeEnergy0bar[:,4],color=palette[0],linewidth=1.)
plt.fill_between(freeEnergy0bar[:,0],freeEnergy0bar[:,2]-freeEnergy0bar[:,4],freeEnergy0bar[:,2]+freeEnergy0bar[:,4],alpha=0.5,color=palette[0])
plt.fill_between(freeEnergy0bar[:,0],freeEnergy0bar[:,5],freeEnergy0bar[:,6],alpha=0.3,color=palette[0])

#plt.plot(freeEnergy0bar[:,0],freeEnergy0bar[:,5],color=palette[0])
#plt.plot(freeEnergy0bar[:,0],freeEnergy0bar[:,6],color=palette[0])
#plt.plot(freeEnergy10000bar[:,0],freeEnergy10000bar[:,2],color=palette[2],label="1 GPa")

plt.plot(freeEnergy10000bar[:,0],freeEnergy10000bar[:,2]+freeEnergy10000bar[:,4],color=palette[2],linewidth=1.)
plt.plot(freeEnergy10000bar[:,0],freeEnergy10000bar[:,2]-freeEnergy10000bar[:,4],color=palette[2],linewidth=1.)
plt.fill_between(freeEnergy10000bar[:,0],freeEnergy10000bar[:,2]-freeEnergy10000bar[:,4],freeEnergy10000bar[:,2]+freeEnergy10000bar[:,4],alpha=0.5,color=palette[2])
plt.fill_between(freeEnergy10000bar[:,0],freeEnergy10000bar[:,5],freeEnergy10000bar[:,6],alpha=0.3,color=palette[2])

plt.errorbar(references0bar[:,0],references0bar[:,1],yerr=references0bar[:,2],fmt='o',markersize=5.,color=palette[0],capsize=4,capthick=1.5)
plt.errorbar(references10000bar[:,0],references10000bar[:,1],yerr=references10000bar[:,2],fmt='o',markersize=5,color=palette[2],capsize=4,capthick=1.5)

plt.xlim([349.5,450.5])
plt.ylim([-50,100])
#plt.xlim([390,410])
#plt.ylim([40,80])

plt.xticks(np.arange(350,475,25))
plt.yticks(np.arange(-50,125,25))

plt.xlabel("Temperature (K)")
plt.ylabel("Free energy (kJ/mol)")
#plt.legend(frameon=False)

plt.text(370,30,"1 bar",color=palette[0])
plt.text(430,30,"1 GPa",color=palette[2])

#plt.savefig("Plot.pdf", bbox_inches='tight')
#plt.savefig("Plot.png", bbox_inches='tight',dpi=300)

plt.show()
# Out:
# /local-1/piaggp/Programs/miniconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
freeEnergies2=np.genfromtxt("/mnt/storage3/piaggp/PhaseDiagramsFromSingleSimulations/Sodium/UseRefCV/Bias/Multithermal-Multibaric/Test4/Reweight/freeEnergies.txt")

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (10, 6)
fig, ax1 = plt.subplots()

x=freeEnergies2[:,0]
y=freeEnergies2[:,1]
x=np.linspace(np.amin(x),np.amax(x),11)
y=np.linspace(np.amin(y),np.amax(y),11)
Z=freeEnergies2[:,2].reshape([11,11])

X, Y= np.meshgrid(x,y,indexing='ij')

#plt.contourf(X,Y/10000,Z,np.arange(-100,100.1,0.1),cmap=my_colormap,vmin=-50,vmax=50,alpha=0.8)
fes = plt.contourf(X,Y/10000,Z,np.arange(-150,150.1,0.1),cmap=my_colormap,vmin=-100,vmax=100)

plt.colorbar(fes,ticks=np.arange(-150,175,25))

plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (GPa)")

plt.xticks(np.arange(350,475,25))
#plt.clim([-50,50])

plt.show()

# %% [markdown]
# ## Reweight

# %%
COLVAR=np.genfromtxt("Test4/Reweight/COLVARtrim")

# %%
CV=COLVAR[:,4]
vesBias=COLVAR[:,5]
energy=COLVAR[:,1]
energy2=np.copy(COLVAR[:,1])
energy-=np.mean(energy)
vol=COLVAR[:,2]
vol2=np.copy(COLVAR[:,2])
vol-=np.mean(vol)
wallBias=COLVAR[:,9]
totalBias=vesBias+wallBias
beta=1./(0.00831441001626*400)
pressure=5000*0.06022140857

# %% [markdown]
# ### Compute mean and errors with batches

# %%
def batch(data,total_batch_num,batch_num):
    if (batch_num<0):
        raise Exception('batch_num must be greater than 0! Start from index 0')
    if (batch_num>(total_batch_num-1)):
        raise Exception('batch_num must be smaller than total_batch_num-1!')
    batch_size=int(data.shape[0]/total_batch_num)
    start=batch_size*batch_num
    end=batch_size*(batch_num+1)
    if (end>data.shape[0]):
        end=data.shape[0]
    return data[start:end]

# %%
def freeEnergies(CV,bias,vol,temperature,pressure,tempPrimes,pressurePrimes,total_batch_num,CVlimit):
    N=tempPrimes.shape[0]
    M=pressurePrimes.shape[0]
    freeEnergiesStruct=np.zeros([N,M,total_batch_num])
    beta=1./(0.00831441001626*temperature)
    for i in range(N):
        betaPrime=1./(0.00831441001626*tempPrimes[i])
        for j in range(M):
            for k in range(total_batch_num):
                probLiquid=np.sum(np.exp(beta*batch(bias[CV<=CVlimit],total_batch_num,k))*np.exp((beta-betaPrime)*batch(energy[CV<=CVlimit],total_batch_num,k)+(beta*pressure-betaPrime*pressurePrimes[j])*batch(vol[CV<=CVlimit],total_batch_num,k)))
                probSolid=np.sum(np.exp(beta*batch(bias[CV>=CVlimit],total_batch_num,k))*np.exp((beta-betaPrime)*batch(energy[CV>=CVlimit],total_batch_num,k)+(beta*pressure-betaPrime*pressurePrimes[j])*batch(vol[CV>=CVlimit],total_batch_num,k)))
                freeEnergiesStruct[i,j,k]=-(1./betaPrime)*np.log(probSolid/probLiquid)
    return freeEnergiesStruct

# %%
N=41
M=41
tempPrimes=np.linspace(350,450,N)
pressurePrimes=0.06022140857*np.linspace(0,10000,M)
temperature=400
pressure=5000*0.06022140857
total_batch_num=20
#freeEnergiesBcc=freeEnergies(CV,totalBias,vol,temperature,pressure,tempPrimes,pressurePrimes,total_batch_num,125)
freeEnergiesBcc=np.load("freeEnergiesBcc.npy")

# %%
#np.save("freeEnergiesBcc.npy", freeEnergiesBcc)

# %%
#freeEnergiesBccErrors=np.zeros([N,M])
freeEnergiesBccErrors=np.std(freeEnergiesBcc,axis=2)
freeEnergiesBccMean=np.mean(freeEnergiesBcc,axis=2)
#freeEnergiesBccMin=freeEnergiesBccMean-freeEnergiesBccErrors
#freeEnergiesBccMax=freeEnergiesBccMean+freeEnergiesBccErrors
freeEnergiesBccMin=np.amin(freeEnergiesBcc,axis=2)
freeEnergiesBccMax=np.amax(freeEnergiesBcc,axis=2)

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (10, 6)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
#plt.contourf(X,Y/10000,Z,np.arange(-100,100.1,0.1),cmap=my_colormap,vmin=-50,vmax=50,alpha=0.8)
#fes = plt.contourf(X,Y,freeEnergiesBccMean,np.arange(-150,150.1,0.1),cmap=cm_fessa,vmin=-100,vmax=100)

#plt.colorbar(fes,ticks=np.arange(-150,200,50))


posmin=np.argmin(abs(freeEnergiesBccMean),axis=0)
#print(x[posmin])


from scipy.interpolate import interp1d, BSpline, splev, splrep
#f = interp1d(y, x[posmin], kind='nearest')
#f = BSpline(y,x, 2)
f = splrep(y,x[posmin],s=100)

y2=np.linspace(np.amin(y),np.amax(y),100)

plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.)
plt.scatter(x[posmin],y,color='red',alpha=0.6,s=40,linewidths=0.)

plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (GPa)")

plt.xticks(np.arange(350,475,25))
#plt.clim([-50,50])

plt.text(390,0.6,"BCC",color="black",alpha=0.7)
plt.text(425,0.25,"Liquid",color="black",alpha=0.7)

ax1.fill([350,350,441,431,421,410,397,380],[0,1,1,0.8,0.6,0.4,0.2,0], fill=False, hatch='ooo',color=palette[0],alpha=0.6,linewidth=0.)

ax1.set_xlim([350,450])
ax1.set_ylim([0,1])

plt.show()

# %%
plt.plot(np.linspace(340,460,2),0.*np.linspace(340,460,2),'--',color='black',alpha=0.5)

x=np.linspace(350,450,N)

#plt.plot(x,freeEnergiesBccMean[:,0],color=palette[0],linewidth=2.)
#plt.plot(x,freeEnergiesBccMean[:,0]-freeEnergiesBccErrors[:,0],color=palette[0],linewidth=1.)
plt.fill_between(x,freeEnergiesBccMean[:,0]-freeEnergiesBccErrors[:,0],freeEnergiesBccMean[:,0]+freeEnergiesBccErrors[:,0],alpha=0.8,color=palette[0],linewidth=0.)
plt.fill_between(x,freeEnergiesBccMin[:,0],freeEnergiesBccMax[:,0],alpha=0.3,color=palette[0],linewidth=0.)

#plt.plot(x,freeEnergiesBccMean[:,M-1]+freeEnergiesBccErrors[:,M-1],color=palette[2],linewidth=2.)
#plt.plot(x,freeEnergiesBccMean[:,M-1]-freeEnergiesBccErrors[:,M-1],color=palette[2],linewidth=1.)
plt.fill_between(x,freeEnergiesBccMean[:,M-1]-freeEnergiesBccErrors[:,M-1],freeEnergiesBccMean[:,M-1]+freeEnergiesBccErrors[:,M-1],alpha=0.8,color=palette[2],linewidth=0.)
plt.fill_between(x,freeEnergiesBccMin[:,M-1],freeEnergiesBccMax[:,M-1],alpha=0.3,color=palette[2],linewidth=0.)

plt.errorbar(references0bar[:,0],-references0bar[:,1],yerr=references0bar[:,2],fmt='o',markersize=5.,color=palette[0],capsize=4,capthick=1.5)
plt.errorbar(references10000bar[:,0],-references10000bar[:,1],yerr=references10000bar[:,2],fmt='o',markersize=5,color=palette[2],capsize=4,capthick=1.5)

plt.xlim([349.5,450.5])
plt.ylim([-100,50])
#plt.xlim([360,385])
#plt.ylim([-20,0])
#plt.xlim([390,410])
#plt.ylim([40,80])

plt.xticks(np.arange(350,475,25))
plt.yticks(np.arange(-100,75,25))

plt.xlabel("Temperature (K)")
plt.ylabel(r"$\Delta G_{l\rightarrow bcc}$ (kJ/mol)")
#plt.legend(frameon=False)

plt.text(370,10,"1 bar",color=palette[0])
plt.text(430,10,"1 GPa",color=palette[2])

#plt.savefig("Plot.pdf", bbox_inches='tight')
#plt.savefig("Plot.png", bbox_inches='tight',dpi=300)

plt.show()

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 9}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (7, 2.5)

fig = plt.figure() #figsize=plt.figaspect(0.5))

#ax1 = fig.add_subplot(2, 2, 1)
#ax3 = fig.add_subplot(2, 2, 2, projection='3d')
#ax2 = fig.add_subplot(2, 2, 3)
#ax4 = fig.add_subplot(2, 2, 4)

ax1 = plt.subplot2grid((3,2), (0,0), colspan=1, rowspan=1)
ax2 = plt.subplot2grid((3,2), (1,0), colspan=1, rowspan=1) #, projection='3d')
ax3 = plt.subplot2grid((3,2), (2,0), colspan=1, rowspan=1)
ax4 = plt.subplot2grid((3,2), (0,1), colspan=1, rowspan=1)
ax5 = plt.subplot2grid((3,2), (1,1), colspan=1, rowspan=1) #, projection='3d')
ax6 = plt.subplot2grid((3,2), (2,1), colspan=1, rowspan=1)
indeces=np.r_[0:14000,30000:94000,120000:CV.shape[0]]
print(indeces)

#plt.plot(indeces)
#plt.plot(CV)
x=np.linspace(0,energy2.shape[0]/1000,energy2.shape[0])

ax1.plot(x,energy2,linewidth=0.05,color=palette[0])
ax2.plot(x,vol2,linewidth=0.05,color=palette[2])
ax3.plot(x,CV,linewidth=0.05,color=palette[4])

ax1.set_xticks(np.arange(0,120,20))
ax2.set_xticks(np.arange(0,120,20))
ax3.set_xticks(np.arange(0,120,20))

ax1.set_xlim([0,100])
ax2.set_xlim([0,100])
ax3.set_xlim([0,100])
ax4.set_xlim([0,50])
ax5.set_xlim([0,50])
ax6.set_xlim([0,50])

ax1.set_xticklabels([])
ax2.set_xticklabels([])
ax4.set_xticklabels([])
ax5.set_xticklabels([])

ax3.set_xlabel("Time (ns)")
ax6.set_xlabel("Time (ns)")

ref = np.genfromtxt("/mnt/storage3/piaggp/PhaseDiagramsFromSingleSimulations/Sodium/UseRefCV/References/Pressure1/Temp375K/COLVAR")    
                    
ax4.plot(ref[:,0]/1000,ref[:,1],color=palette[0],alpha=1.0,linewidth=0.05)
ax5.plot(ref[:,0]/1000,ref[:,2],color=palette[2],alpha=1.0,linewidth=0.05)
ax6.plot(ref[:,0]/1000,ref[:,4],color=palette[4],alpha=1.0,linewidth=0.1)

#ax2.set_yticks(np.arange(2.8,5.2,0.8))
#ax5.set_yticks(np.arange(2.8,5.2,0.8))

ax1.set_ylim([-26500,-23000])
ax4.set_ylim([-26500,-23000])
ax2.set_ylim([8,12])
ax5.set_ylim([8,12])
ax3.set_ylim([0,250])
ax6.set_ylim([0,250])

ax4.set_yticklabels([])
ax5.set_yticklabels([])
ax6.set_yticklabels([])

#ax4.set_yticks([-80000,-70000,-60000,-50000])
#ax1.set_yticks([-80000,-70000,-60000,-50000])
ax1.set_yticklabels(["-26","-26","-24"])
ax1.text(0,-22700,r"x$10^3$",ha='left',va='center')


ax3.set_yticks([0,125,250])
ax6.set_yticks([0,125,250])

ax1.set_ylabel("Energy \n(kJ/mol)")
ax2.set_ylabel("Volume \n"+ r" (nm$^3$)")
ax3.set_ylabel(r"$s$")

ax1.text(50,-22500,r"multithermal-multibaric",ha='center',va='center')
#ax1.text(60,-47000,r"biased ensemble",ha='center',va='center')

ax4.text(25,-22500,"isothermal-isobaric",ha='center',va='center')
#ax4.text(25,-47000,r"biased ensemble",ha='center',va='center')

#plt.savefig("/home/piaggp/Desktop/plot-SI-al-fcc-traj.pdf", bbox_inches='tight')
plt.savefig("/home/piaggp/Desktop/plot-SI-na-traj.png", bbox_inches='tight',dpi=300)

plt.show()
# Out:
# [    0     1     2 ..., 93997 93998 93999]

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 9}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (3.5, 2.5)

fig = plt.figure() #figsize=plt.figaspect(0.5))

x=energy2
y=vol2
cv=CV
plt.scatter(x[cv<125],y[cv<125],s=0.5,color=palette[0],alpha=1.0,edgecolors='none')
plt.scatter(x[cv>125],y[cv>125],s=0.5,color=palette[1],alpha=1.0,edgecolors='none')

x=ref[10000:,1]
y=ref[10000:,2]
cv=ref[10000:,4]
plt.scatter(x[cv>125],y[cv>125],s=0.05,color=palette[3],alpha=1.0,edgecolors='none')
plt.scatter(x[cv<125],y[cv<125],s=0.05,color=palette[2],alpha=1.0,edgecolors='none')

plt.yticks(np.arange(8,13,1))
plt.xticks([-27000,-25000,-23000],["-27","-25","-23"])
plt.text(-22900,8,r"x$10^3$",ha='left',va='center')

plt.xlim([-27000,-23000])
plt.ylim([8,12])

plt.xlabel("Energy (kJ/mol)")
plt.ylabel(r"Volume (nm$^3$)")


ax = plt.subplot(111)
ax.add_patch(plt.Rectangle((-22750,8.5),2900, 1.5,facecolor='white',edgecolor='black',
                              clip_on=False,linewidth = 0.75))
ax.add_patch(plt.Rectangle((-22750,10.5),2900, 1.5,facecolor='white',edgecolor='black',
                              clip_on=False,linewidth = 0.75))

from matplotlib.patches import Ellipse

ax.add_patch(Ellipse((-22500,11.25),100,0.15,facecolor=palette[0],
                              clip_on=False,linewidth = 0.))
ax.add_patch(Ellipse((-22500,10.8),100,0.15,facecolor=palette[1],
                              clip_on=False,linewidth = 0.))

ax.add_patch(Ellipse((-22500,9.25),100,0.15,facecolor=palette[2],
                              clip_on=False,linewidth = 0.))
ax.add_patch(Ellipse((-22500,8.8),100,0.15,facecolor=palette[3],
                              clip_on=False,linewidth = 0.))

ax.text(-22600,11.6,"multithermal-multibaric")
ax.text(-22600,9.6,"isothermal-isobaric 375 K - 1 bar")

ax.text(-22400,11.175,"liquid")
ax.text(-22400,10.725,"bcc")

ax.text(-22400,9.175,"liquid")
ax.text(-22400,8.725,"bcc")

#plt.savefig("/home/piaggp/Desktop/plot-SI-al-fcc-EV.pdf", bbox_inches='tight')
plt.savefig("/home/piaggp/Desktop/plot-SI-na-EV.png", bbox_inches='tight',dpi=300)

plt.show()
# Out:
# /local-1/piaggp/Programs/miniconda/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
def orderParameterMean(CV,bias,vol,temperature,pressure,tempPrimes,pressurePrimes):
    N=tempPrimes.shape[0]
    M=pressurePrimes.shape[0]
    OPM=np.zeros([N,M])
    beta=1./(0.00831441001626*temperature)
    for i in range(N):
        betaPrime=1./(0.00831441001626*tempPrimes[i])
        for j in range(M):
            mean=np.sum(CV*np.exp(beta*bias)*np.exp((beta-betaPrime)*energy+(beta*pressure-betaPrime*pressurePrimes[j])*vol))
            norm=np.sum(np.exp(beta*bias)*np.exp((beta-betaPrime)*energy+(beta*pressure-betaPrime*pressurePrimes[j])*vol))
            OPM[i,j]=mean/norm
    return OPM

# %%
N=161
M=161
tempPrimes=np.linspace(350,450,N)
pressurePrimes=0.06022140857*np.linspace(0,10000,M)
temperature=400
pressure=5000*0.06022140857
OPM=np.load("orderParameterBcc.npy")
#OPM=orderParameterMean(CV,totalBias,vol,temperature,pressure,tempPrimes,pressurePrimes)

# %%
np.save("orderParameterBcc.npy", OPM)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)
X,Y=np.meshgrid(x,y,indexing='ij')

fig = plt.figure(figsize=(20,12))
ax = fig.gca(projection='3d')

ax.plot_surface(X,Y,OPM/250.,cmap=my_colormap,vmin=0,vmax=1,alpha=1)

ax.view_init(30, 260)

plt.show()

# rotate the axes and update
#for angle in range(0, 2):
#    ax.view_init(30, angle)
#    plt.show()
#    plt.pause(.1)

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (10, 6)
fig, ax1 = plt.subplots()

N=161
M=161

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
#plt.contourf(X,Y/10000,Z,np.arange(-100,100.1,0.1),cmap=my_colormap,vmin=-50,vmax=50,alpha=0.8)
fes = plt.contourf(X,Y,OPM/250.,np.arange(0.,1.1,0.1),cmap=cm_fessa,vmin=0,vmax=1)

plt.colorbar(fes,ticks=np.arange(0,1.5,0.5))


posmin=np.argmin(abs(freeEnergiesBccMean),axis=0)
#print(x[posmin])

from scipy.interpolate import interp1d, BSpline, splev, splrep
N=41
M=41
x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

#f = interp1d(y, x[posmin], kind='nearest')
#f = BSpline(y,x, 2)
f = splrep(y,x[posmin],s=100)

y2=np.linspace(np.amin(y),np.amax(y),100)

plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.)
#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)

plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (GPa)")

plt.xticks(np.arange(350,475,25))
#plt.clim([-50,50])

plt.text(390,0.6,"BCC",color="black",alpha=0.7)
plt.text(425,0.25,"Liquid",color="black",alpha=0.7)

plt.show()

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 9}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (7, 5)

fig = plt.figure() #figsize=plt.figaspect(0.5))

#ax1 = fig.add_subplot(2, 2, 1)
#ax3 = fig.add_subplot(2, 2, 2, projection='3d')
#ax2 = fig.add_subplot(2, 2, 3)
#ax4 = fig.add_subplot(2, 2, 4)

ax1 = plt.subplot2grid((10,10), (0,0), colspan=4, rowspan=4)
ax2 = plt.subplot2grid((10,10), (5,0), colspan=4, rowspan=4)
#ax3 = plt.subplot2grid((10,10), (0,5), colspan=4, rowspan=4)
ax3 = plt.subplot2grid((10,10), (0,5), colspan=4, rowspan=4, projection='3d')
ax4 = plt.subplot2grid((10,10), (5,5), colspan=4, rowspan=4, projection='3d')

#ax4 = plt.subplot2grid((10,10), (5,5), colspan=5, rowspan=4)

#################
# Subplot 1
#################

N=41
M=41
x=np.linspace(350,450,N)
y=np.linspace(0,1,M)
X,Y=np.meshgrid(x,y,indexing='ij')

#fes = ax1.contourf(X,Y,freeEnergiesBccMean,np.arange(-150,150.1,0.1),cmap=cm_fessa2,vmin=-100,vmax=100)

#cbar = plt.colorbar(fes,ax=ax1,ticks=np.arange(-150,200,50))
#cbar.set_label(r"$\Delta G_{l\rightarrow bcc}$ (kJ/mol)")

import matplotlib as mpl
#mpl.rcParams['hatch.linewidth'] = 0.1  # previous pdf hatch linewidth
mpl.rcParams['hatch.linewidth'] = 0.5
ax1.fill([350,350,441,431,421,410,397,380],[0,1,1,0.8,0.6,0.4,0.2,0], fill=False, hatch='ooo',color=palette[2],alpha=0.6,linewidth=0.)
ax1.fill([441,431,421,410,397,380,450,450],[1,0.8,0.6,0.4,0.2,0,0,1], fill=False, hatch='ooo',color=palette[0],alpha=0.6,linewidth=0.)


posmin=np.argmin(abs(freeEnergiesBccMean),axis=0)
from scipy.interpolate import interp1d, BSpline, splev, splrep
f = splrep(y,x[posmin],s=100)
y2=np.linspace(np.amin(y),np.amax(y),100)
ax1.plot(splev(y2,f),y2,color='grey',linewidth=2.)
#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)

ax1.set_xlabel("Temperature (K)")
ax1.set_ylabel("Pressure (GPa)")
ax1.set_xticks(np.arange(350,475,25))
#plt.clim([-50,50])

ax1.text(380,0.65,"BCC",color="black",ha='center',va='center')
ax1.text(430,0.3,"Liquid",color="black",ha='center',va='center')

ax1.text(410,0.47,r"$\Delta G_{l\rightarrow bcc}=0$",color="black",rotation=48,va='center',ha='center',fontsize=8)

ax1.set_xlim([350,450])
ax1.set_ylim([0,1])

ax1.text(350,-0.24,r"(a)")

#################
# Subplot 2
#################

x=np.linspace(340,460,5)
y=x*0.
ax2.plot(x,y,'--',linewidth=1,color="black",alpha=0.5)

#x=np.linspace(1400,2600,5)
#y=x*0.+0.00831441001626*x*20
#ax2.plot(x,y,'--',linewidth=0.5,color="black",alpha=0.5)
#ax2.plot(x,-y,'--',linewidth=0.5,color="black",alpha=0.5)
#ax2.fill_between(x,y,1000,color="black",alpha=0.05)
#ax2.fill_between(x,-y,-1000,color="black",alpha=0.05)

#ax2.plot(np.linspace(340,460,2),0.*np.linspace(340,460,2),'--',color='black',alpha=0.5,linewidth=0.75)

x=np.linspace(350,450,N)

ax2.fill_between(x,freeEnergiesBccMean[:,0]-freeEnergiesBccErrors[:,0],freeEnergiesBccMean[:,0]+freeEnergiesBccErrors[:,0],alpha=0.6,color=palette[0],linewidth=0.)
#ax2.fill_between(x,freeEnergiesBccMin[:,0],freeEnergiesBccMax[:,0],alpha=0.3,color=palette[0],linewidth=0.)

ax2.fill_between(x,freeEnergiesBccMean[:,M-1]-freeEnergiesBccErrors[:,M-1],freeEnergiesBccMean[:,M-1]+freeEnergiesBccErrors[:,M-1],alpha=0.6,color=palette[2],linewidth=0.)
#ax2.fill_between(x,freeEnergiesBccMin[:,M-1],freeEnergiesBccMax[:,M-1],alpha=0.3,color=palette[2],linewidth=0.)

#ax2.errorbar(references0bar[:,0],-references0bar[:,1],yerr=references0bar[:,2],fmt='o',markersize=1.,color=palette[0],capsize=2,capthick=0.5)
#ax2.errorbar(references10000bar[:,0],-references10000bar[:,1],yerr=references10000bar[:,2],fmt='o',markersize=1,color=palette[2],capsize=2,capthick=0.5)

ax2.scatter(references0bar[:,0],-references0bar[:,1],s=5.,color=palette[0])
ax2.scatter(references10000bar[:,0],-references10000bar[:,1],s=5,color=palette[2])

ax2.set_xlim([349.5,450.5])
ax2.set_ylim([-75,50])
ax2.set_xticks(np.arange(350,475,25))
ax2.set_yticks(np.arange(-75,75,25))

ax2.set_xlabel("Temperature (K)")
ax2.set_ylabel(r"$\Delta G_{l\rightarrow bcc}$ (kJ/mol)")
#plt.legend(frameon=False)

ax2.text(375,20,"1 bar",color=palette[0],ha='center',va='center')
ax2.text(435,20,"1 GPa",color=palette[2],ha='center',va='center')

#ax2.text(350,-105,r"$\textbf{b}$")
ax2.text(350,-105,r"(b)")

#################
# Subplot 3
#################

from mpl_toolkits.mplot3d import Axes3D, art3d

N=161
M=161
x=np.linspace(350,450,N)
y=np.linspace(0,1,M)
X,Y=np.meshgrid(x,y,indexing='ij')

ax3.plot_surface(X,Y,OPM/250.,cmap=my_colormap,vmin=-0.25,vmax=1.25,alpha=1)
ax3.grid(False)
ax3.xaxis.pane.set_edgecolor('black')
ax3.yaxis.pane.set_edgecolor('black')
ax3.zaxis.pane.set_edgecolor('black')
ax3.xaxis.pane.fill = False
ax3.yaxis.pane.fill = False
ax3.zaxis.pane.fill = False

ax3.set_zticks([0,0.5,1])
ax3.set_xticks([350,400,450])
ax3.set_yticks([0,0.5,1])

ax3.set_xlim([350,450])
ax3.set_ylim([0,1])
ax3.set_zlim([0,1])

ax3.set_xlabel("Temperature (K)",labelpad=-1)
ax3.set_ylabel("Pressure (GPa)",labelpad=-1)
ax3.set_zlabel(r"$\langle s \rangle$")

def lims(mplotlims):
    scale = 1.021
    offset = (mplotlims[1] - mplotlims[0])*scale
    return mplotlims[1] - offset, mplotlims[0] + offset

ax3.plot([348.5,348.5],[-0.03,-0.03],[-0.025,1.025],color="black",linewidth=0.9,alpha=0.6)
#xlims, ylims, zlims = lims(ax3.get_xlim()), lims(ax3.get_ylim()), lims(ax3.get_zlim())
#i = np.array([xlims[0], ylims[0], zlims[0]])
#f = np.array([xlims[0], ylims[0], zlims[1]])
#p = art3d.Poly3DCollection(np.array([[i, f]]))
#p.set_color('black')
#ax3.add_collection3d(p)

ax3.view_init(30, 290)

ax3.tick_params(pad=-1)

#ax3.text(320,-0.1,-0.9,r"$\textbf{c}$")
ax3.text(320,-0.1,-0.9,r"(c)")

#################
# Subplot 4
#################

from matplotlib.cbook import get_sample_data

ax4.plot_trisurf(xp2,yp2,zp2,color='orange',alpha=0.0) #cmap=cm_fessa,)
ax4.plot_trisurf(xp3,yp3,zp3,color='orange',alpha=0.0) #cmap=cm_fessa)

im = plt.imread(get_sample_data('/home/piaggp/Desktop/mi_clepsidra_2.png'))
size=0.22
newax = fig.add_axes([0.59, 0.23, size, size], anchor='SW', zorder=10)
newax.imshow(im, interpolation='nearest')
newax.axis('off')
           
ax4.view_init(15, 135)

ax4.set_xlim([-26500,-23500])
ax4.set_ylim([8,11.5])
ax4.set_zlim([0,250])

ax4.grid(False)
ax4.xaxis.pane.set_edgecolor('black')
ax4.yaxis.pane.set_edgecolor('black')
ax4.zaxis.pane.set_edgecolor('black')
ax4.xaxis.pane.fill = False
ax4.yaxis.pane.fill = False
ax4.zaxis.pane.fill = False

ax4.set_xlabel("Energy (kJ/mol)",labelpad=-1)
ax4.set_ylabel(r"Volume (nm$^3$)",labelpad=-1)
ax4.set_zlabel(r"$s$",labelpad=-5)

ax4.tick_params(pad=-1.5)
ax4.set_xticks([-26500,-23500])
ax4.set_yticks([8,11])
ax4.set_zticks([0,250])

#ax4.text(-22500,11.35,-250.0,r"$\textbf{d}$")
ax4.text(-22500,11.35,-250.0,r"(d)")

#################
# Plot label
#################

plt.savefig("/home/piaggp/Desktop/plot4-2.pdf", bbox_inches='tight',dpi=300)
#plt.savefig("plot4.png", bbox_inches='tight', dpi=300)

plt.show()

# %% [markdown]
# ## Example exploration region

# %%
dataExample350=np.genfromtxt("Test4/ReweightEnergyCV-0GPa/fes350")
dataExample375=np.genfromtxt("Test4/ReweightEnergyCV-0GPa/fes375")
dataExample400=np.genfromtxt("Test4/ReweightEnergyCV-0GPa/fes400")
#dataExample425=np.genfromtxt("Test4/ReweightEnergyCV-0GPa/fes425")
#dataExample450=np.genfromtxt("Test4/ReweightEnergyCV-0GPa/fes450")
#dataExampleBiased=np.genfromtxt("Test4/ReweightEnergyCV/histo")

# %%
from mpl_toolkits.mplot3d import Axes3D, art3d

font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 8}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (3.5, 2.5)

fig = plt.figure() #figsize=plt.figaspect(0.5))

ax = fig.gca(projection='3d')


#! SET min_energy -26500
#! SET max_energy -23500
#! SET nbins_energy  300
#! SET periodic_energy false
#! SET min_refcv.morethan -0.5
#! SET max_refcv.morethan 250.5
#! SET nbins_refcv.morethan  300


x=np.linspace(-26500,-23500,301)
y=np.linspace(-0.5,250.5,301)
X,Y=np.meshgrid(x,y,indexing='xy')

#z=dataExample350[:,2].reshape([301,301])
#ax.contourf(X,Y,z,np.arange(0,210,10),cmap=cm_fessa2,zdir='z',offset=100,vmin=0,vmax=200)
#ax.contour(X,Y,z,[15*2.91],zdir='z',offset=100,colors="black")
beta=1.0/(0.008314410016255453*375)
print(1./beta)

#z=dataExampleBiased[:,2].reshape([301,301])
#ax.contour(X,Y,z,[0.04*np.nanmax(z)],zdir='z',offset=0,colors="black")
#ax.contourf(X,Y,z,np.linspace(0.025*np.nanmax(z),1.*np.nanmax(z),10),zdir='z',offset=0,cmap=plt.get_cmap("binary"),alpha=0.5,vmin=0.,vmax=0.05*np.nanmax(z))

threshold=26

z=dataExample375[:,2].reshape([301,301])
ax.contourf(X,Y,z,np.arange(0,210,10),cmap=my_colormap,zdir='z',offset=400,vmin=0,vmax=200)
ax.contourf(X,Y,X*0.+400,10,cmap=plt.get_cmap("binary"),zdir='z',offset=399,vmin=-0.1,vmax=0.,alpha=0.1)
ax.contour(X,Y,z,[threshold/beta],zdir='z',offset=400,colors="black",alpha=0.8,linewidths=0.5)
ax.text(-23500,-10,400,"375 K")

betaPrime=1.0/(0.008314410016255453*400)
#z400=beta*dataExample375[:,2].reshape([301,301])+(betaPrime-beta)*X
#z400 -= np.amin(z400)
#z400 /= betaPrime
#z=dataExample450[:,2].reshape([301,301])
#ax.contourf(X,Y,z400,np.arange(0,210,10),cmap=cm_fessa2,zdir='z',offset=600,vmin=0,vmax=200)
#ax.contour(X,Y,z400,[15/betaPrime],zdir='z',offset=600,colors="black")
#ax.text(-24000,-10,600,"400 K - f")

z=dataExample400[:,2].reshape([301,301])
ax.contourf(X,Y,z,np.arange(0,210,10),cmap=my_colormap,zdir='z',offset=600,vmin=0,vmax=200)
ax.contourf(X,Y,X*0.+600,10,cmap=plt.get_cmap("binary"),zdir='z',offset=599,vmin=-0.1,vmax=0.,alpha=0.1)
ax.contour(X,Y,z,[threshold/betaPrime],zdir='z',offset=600,colors="black",alpha=0.8,linewidths=0.5)
ax.text(-23500,-10,600,"400 K")

betaPrime=1.0/(0.008314410016255453*350)
#z350=beta*dataExample375[:,2].reshape([301,301])+(betaPrime-beta)*X
#z350 -= np.amin(z350)
#z350 /= betaPrime
#z=dataExample400[:,2].reshape([301,301])
#ax.contourf(X,Y,z350,np.arange(0,210,10),cmap=cm_fessa2,zdir='z',offset=200,vmin=0,vmax=200)
#ax.contour(X,Y,z350,[15/betaPrime],zdir='z',offset=200,colors="black")
#ax.text(-24000,-10,200,"350 K -f")

#xlims, ylims, zlims = lims(ax.get_xlim()), lims(ax.get_ylim()), lims(ax.get_zlim())

z=dataExample350[:,2].reshape([301,301])
ax.contourf(X,Y,X*0.+200,10,cmap=plt.get_cmap("binary"),zdir='z',offset=199,vmin=-0.1,vmax=0.,alpha=0.1)
mycontour = ax.contourf(X,Y,z,np.arange(0,210,10),cmap=my_colormap,zdir='z',offset=200,vmin=0,vmax=200)
ax.contour(X,Y,z,[threshold/betaPrime],zdir='z',offset=200,colors="black",alpha=0.8,linewidths=0.5)
#ax.contour(X,Y,z,zdir='x', offset=-25000)
#ax.contour(X,Y,z,5,zdir='x', offset=-23500)

ax.text(-23500,-10,200,"350 K")


temp=np.linspace(350,400,11)
target=np.zeros([301,301])
for i in range(10):
    beta=1.0/(0.008314410016255453*temp[i])
    data=np.genfromtxt("Test4/ReweightEnergyCV-0GPa/fes" + str(int(temp[i])))
    z=data[:,2].reshape([301,301])
    target[z<threshold/beta]=1.
ax.contourf(X,Y,target,10,zdir='z',offset=0,cmap=plt.get_cmap("binary"),alpha=0.6)

ax.set_zlim([0,700])
ax.set_xlim([-26500,-23500])
ax.set_ylim([0,250])

#ax.grid(False)
ax.xaxis.pane.set_edgecolor('black')
ax.yaxis.pane.set_edgecolor('black')
ax.zaxis.pane.set_edgecolor('black')
#ax.xaxis.pane.fill = False
#ax.yaxis.pane.fill = False
#ax.zaxis.pane.fill = False

ax.set_xlabel("Energy",labelpad=-12)
ax.set_ylabel(r"Order parameter",labelpad=-12)

ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_zticklabels([])

ax.text(-25750,150,0,r"$p(E,s)$",va="center",ha="center")
ax.view_init(30, 210)

plt.colorbar(mycontour,ticks=np.arange(0,250,50),shrink=0.5,label="Free energy (kJ/mol)")

#plt.tight_layout()

plt.savefig("/home/piaggp/Desktop/plot-levels.pdf", bbox_inches='tight')

plt.show()
# Out:
# 3.117903756095795

# %% [markdown]
# ### Volume mean

# %%
N=41
M=41
tempPrimes=np.linspace(350,450,N)
pressurePrimes=0.06022140857*np.linspace(0,10000,M)
temperature=400
pressure=5000*0.06022140857
volMean=orderParameterMean(vol2,totalBias,vol,temperature,pressure,tempPrimes,pressurePrimes)

# %%
print(np.mean(vol2))
# Out:
# 9.64715840302

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15, 9)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
fes = plt.contourf(X,Y,volMean,40,cmap=cm_fessa) #,vmin=-100,vmax=100)

plt.colorbar(fes) #,ticks=np.arange(-150,200,50))

#posmin=np.argmin(abs(volMean),axis=0)
#print(x[posmin])

#from scipy.interpolate import interp1d, BSpline, splev, splrep
#f = splrep(y,x[posmin],s=100)

#y2=np.linspace(np.amin(y),np.amax(y),100)

#plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.)
#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)

f = splrep(y,x[posmin],s=100)
y2=np.linspace(np.amin(y),np.amax(y),100)
plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.,alpha=0.5)

#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)
plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (GPa)")

plt.xticks(np.arange(350,475,25))
#plt.clim([-50,50])

plt.text(390,0.6,"BCC",color="black",alpha=0.7)
plt.text(425,0.25,"Liquid",color="black",alpha=0.7)

plt.title("Volume")

plt.show()
# Out:
# /local-1/piaggp/Programs/miniconda/lib/python3.6/site-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Energy mean

# %%
N=41
M=41
tempPrimes=np.linspace(350,450,N)
pressurePrimes=0.06022140857*np.linspace(0,10000,M)
temperature=400
pressure=5000*0.06022140857
energyMean=orderParameterMean(energy2,totalBias,vol,temperature,pressure,tempPrimes,pressurePrimes)

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15, 9)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
fes = plt.contourf(X,Y,energyMean,50,cmap=cm_fessa) #,vmin=-100,vmax=100)

plt.colorbar(fes) #,ticks=np.arange(-150,200,50))

#posmin=np.argmin(abs(volMean),axis=0)
#print(x[posmin])

#from scipy.interpolate import interp1d, BSpline, splev, splrep
#f = splrep(y,x[posmin],s=100)

#y2=np.linspace(np.amin(y),np.amax(y),100)

#plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.)
#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)

f = splrep(y,x[posmin],s=100)
y2=np.linspace(np.amin(y),np.amax(y),100)
plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.,alpha=0.5)

#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)
plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (GPa)")

plt.xticks(np.arange(350,475,25))
#plt.clim([-50,50])

plt.text(390,0.6,"BCC",color="black",alpha=0.7)
plt.text(425,0.25,"Liquid",color="black",alpha=0.7)

plt.title("Potential energy")

plt.show()

# %% [markdown]
# ### Total energy

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15, 9)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
KE=250*3*0.5*0.00831441001626*X
fes = plt.contourf(X,Y,energyMean+KE,50,cmap=cm_fessa) #,vmin=-100,vmax=100)

plt.colorbar(fes) #,ticks=np.arange(-150,200,50))

#posmin=np.argmin(abs(volMean),axis=0)
#print(x[posmin])

#from scipy.interpolate import interp1d, BSpline, splev, splrep
#f = splrep(y,x[posmin],s=100)

#y2=np.linspace(np.amin(y),np.amax(y),100)

#plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.)
#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)

f = splrep(y,x[posmin],s=100)
y2=np.linspace(np.amin(y),np.amax(y),100)
plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.,alpha=0.5)

#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)
plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (GPa)")

plt.xticks(np.arange(350,475,25))
#plt.clim([-50,50])

plt.text(390,0.6,"BCC",color="black",alpha=0.7)
plt.text(425,0.25,"Liquid",color="black",alpha=0.7)

plt.title("Total energy")

plt.show()

# %% [markdown]
# ### PV term

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15, 9)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
PV=np.multiply(Y*10000*0.06022140857,volMean)
#print(Y[0,0],volMean[0,0],Y[0,0]*volMean[0,0]*10000*0.06022140857,PV[0,0])
#print(Y[40,0],volMean[40,0],Y[40,0]*volMean[40,0]*10000*0.06022140857,PV[40,0])
#print(Y[0,40],volMean[0,40],Y[0,40]*volMean[0,40]*10000*0.06022140857,PV[0,40])
#print(Y[40,40],volMean[40,40],Y[40,40]*volMean[40,40]*10000*0.06022140857,PV[40,40])

fes = plt.contourf(X,Y,PV,50,cmap=cm_fessa) #,vmin=-100,vmax=100)

plt.colorbar(fes) #,ticks=np.arange(-150,200,50))

#posmin=np.argmin(abs(volMean),axis=0)
#print(x[posmin])

#from scipy.interpolate import interp1d, BSpline, splev, splrep
#f = splrep(y,x[posmin],s=100)

#y2=np.linspace(np.amin(y),np.amax(y),100)

#plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.)
#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)

f = splrep(y,x[posmin],s=100)
y2=np.linspace(np.amin(y),np.amax(y),100)
plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.,alpha=0.5)

#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)
plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (GPa)")

#plt.xticks(np.arange(350,475,25))
#plt.clim([-50,50])

#plt.ylim([0,0.1])

#plt.text(390,0.6,"BCC",color="black",alpha=0.7)
#plt.text(425,0.25,"Liquid",color="black",alpha=0.7)

plt.title("PV")

plt.show()

# %% [markdown]
# ### Enthalpy

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15, 9)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
KE=250*3*0.5*0.00831441001626*X
PV=Y*10000*0.06022140857*volMean
fes = plt.contourf(X,Y,energyMean+KE+PV,50,cmap=cm_fessa) #,vmin=-100,vmax=100)

plt.colorbar(fes) #,ticks=np.arange(-150,200,50))

#posmin=np.argmin(abs(volMean),axis=0)
#print(x[posmin])

#from scipy.interpolate import interp1d, BSpline, splev, splrep
#f = splrep(y,x[posmin],s=100)

#y2=np.linspace(np.amin(y),np.amax(y),100)

#plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.)
#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)

f = splrep(y,x[posmin],s=100)
y2=np.linspace(np.amin(y),np.amax(y),100)
plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.,alpha=0.5)

#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)
plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (GPa)")

plt.xticks(np.arange(350,475,25))
#plt.clim([-50,50])

plt.text(390,0.6,"BCC",color="black",alpha=0.7)
plt.text(425,0.25,"Liquid",color="black",alpha=0.7)

plt.title("Enthalpy")

plt.show()

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15, 9)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
KE=250*3*0.5*0.00831441001626*X
PV=np.multiply(Y*10000*0.06022140857,volMean)
#fes = plt.contourf(X,Y,PV,50,cmap=cm_fessa) #,vmin=-100,vmax=100)
enthalpy=energyMean+KE+PV

#plt.plot(x,np.gradient(enthalpy[:,0] )/ (5.*250*0.00831441001626/2.),label="0 GPa")
#plt.plot(x,np.gradient(enthalpy[:,20])/ (5.*250*0.00831441001626/2.),label="0.5 GPa")
#plt.plot(x,np.gradient(enthalpy[:,40])/ (5.*250*0.00831441001626/2.),label="1 GPa")

plt.plot(x,np.gradient(enthalpy[:,0] )*1000/ 250,label="0 GPa")
plt.plot(x,np.gradient(enthalpy[:,20])*1000/ 250,label="0.5 GPa")
plt.plot(x,np.gradient(enthalpy[:,40])*1000/ 250,label="1 GPa")

plt.xlabel("Temperature (K)")
plt.ylabel(r"$C_P$ (J/mol K)")

plt.legend()

plt.ylim([50,1000])
plt.title(r"$C_P$")

plt.show()

# %% [markdown]
# ### Entropy

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15, 9)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
KE=250*3*0.5*0.00831441001626*X
PV=np.multiply(Y*10000*0.06022140857,volMean)
#fes = plt.contourf(X,Y,PV,50,cmap=cm_fessa) #,vmin=-100,vmax=100)
fes = plt.contourf(X,Y,(energyMean+KE+PV-freeEnergiesBccMean)/X,50,cmap=cm_fessa) #,vmin=-100,vmax=100)

plt.colorbar(fes) #,ticks=np.arange(-150,200,50))

#posmin=np.argmin(abs(volMean),axis=0)
#print(x[posmin])

#from scipy.interpolate import interp1d, BSpline, splev, splrep
#f = splrep(y,x[posmin],s=100)

#y2=np.linspace(np.amin(y),np.amax(y),100)

#plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.)
#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)

f = splrep(y,x[posmin],s=100)
y2=np.linspace(np.amin(y),np.amax(y),100)
plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.,alpha=0.5)

#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)
plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (GPa)")

plt.xticks(np.arange(350,475,25))
#plt.clim([-50,50])

plt.text(390,0.6,"BCC",color="black",alpha=0.7)
plt.text(425,0.25,"Liquid",color="black",alpha=0.7)

plt.title("Entropy")

plt.show()

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15, 9)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
KE=250*3*0.5*0.00831441001626*X
PV=np.multiply(Y*10000*0.06022140857,volMean)
#fes = plt.contourf(X,Y,PV,50,cmap=cm_fessa) #,vmin=-100,vmax=100)
entropy=(energyMean+KE+PV-freeEnergiesBccMean)/X

plt.plot(x,entropy[:,0],label="0 GPa")
plt.plot(x,entropy[:,20],label="0.5 GPa")
plt.plot(x,entropy[:,40],label="1 GPa")

plt.xlabel("Temperature (K)")
plt.ylabel("Entropy (kJ/mol K)")

plt.legend()

plt.title("Entropy")

plt.show()

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15, 9)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
KE=250*3*0.5*0.00831441001626*X
PV=np.multiply(Y*10000*0.06022140857,volMean)
#fes = plt.contourf(X,Y,PV,50,cmap=cm_fessa) #,vmin=-100,vmax=100)
entropy=(energyMean+KE+PV-freeEnergiesBccMean)/X

plt.plot(x,np.gradient(entropy[:,0] ),label="0 GPa")
plt.plot(x,np.gradient(entropy[:,20]),label="0.5 GPa")
plt.plot(x,np.gradient(entropy[:,40]),label="1 GPa")

plt.xlabel("Temperature (K)")
plt.ylabel(r"Entropy (kJ/mol K$^2$)")

plt.legend()

plt.title("Entropy derivative")

plt.show()

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15, 9)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
KE=250*3*0.5*0.00831441001626*X
PV=np.multiply(Y*10000*0.06022140857,volMean)
#fes = plt.contourf(X,Y,PV,50,cmap=cm_fessa) #,vmin=-100,vmax=100)
entropy=(energyMean+KE+PV-freeEnergiesBccMean)/X

plt.plot(y,entropy[0,:],label="0 GPa")
plt.plot(y,entropy[20,:],label="0.5 GPa")
plt.plot(y,entropy[40,:],label="1 GPa")

plt.xlabel("Pressure (GPa)")
plt.ylabel("Entropy (kJ/mol K)")

plt.legend()

plt.title("Entropy")

plt.show()

# %%
font = {'family' : 'serif',
        'serif'   : 'palatino',
        #'sans-serif'    : 'Computer Modern Sans serif', 
        'style'   : 'normal',
        'variant'   : 'normal',
        'stretch'   : 'normal',
        'weight'   : 'normal',
        'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)
plt.rcParams['figure.figsize'] = (15, 9)
fig, ax1 = plt.subplots()

N=41
M=41

x=np.linspace(350,450,N)
y=np.linspace(0,1,M)

X,Y=np.meshgrid(x,y,indexing='ij')
fes = plt.contourf(X,Y,-np.gradient(freeEnergiesBccMean,axis=0),50,cmap=cm_fessa) #,vmin=-100,vmax=100)

plt.colorbar(fes) #,ticks=np.arange(-150,200,50))

#posmin=np.argmin(abs(volMean),axis=0)
#print(x[posmin])

#from scipy.interpolate import interp1d, BSpline, splev, splrep
#f = splrep(y,x[posmin],s=100)

#y2=np.linspace(np.amin(y),np.amax(y),100)

#plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.)
#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)

f = splrep(y,x[posmin],s=100)
y2=np.linspace(np.amin(y),np.amax(y),100)
plt.plot(splev(y2,f),y2,'--',color='black',linewidth=2.,alpha=0.5)

#plt.scatter(x[posmin],y,color='black',alpha=0.6,s=10,linewidths=0.)
plt.xlabel("Temperature (K)")
plt.ylabel("Pressure (GPa)")

plt.xticks(np.arange(350,475,25))
#plt.clim([-50,50])

plt.text(390,0.6,"BCC",color="black",alpha=0.7)
plt.text(425,0.25,"Liquid",color="black",alpha=0.7)

plt.title("Entropy")

plt.show()

# %%
data4d=np.genfromtxt("/mnt/storage3/piaggp/PhaseDiagramsFromSingleSimulations/Sodium/UseRefCV/Bias/Multithermal-Multibaric/Test4/corr.targetdist.b1.iter-35000.data")

# %%
w=data4d[:,3].reshape([41,41,41])
x=np.linspace(np.amin(data4d[:,0]),np.amax(data4d[:,0]),41)
y=np.linspace(np.amin(data4d[:,1]),np.amax(data4d[:,1]),41)
z=np.linspace(np.amin(data4d[:,2]),np.amax(data4d[:,2]),41)
X,Y = np.meshgrid(x,y,indexing='xy')

#print(np.amax(w),0.0000005)
mymin=np.argmin(abs(w[:21,:,:]-5e-7),axis=0)
Z1 = z[mymin]
mymin=np.argmin(abs(w[22:,:,:]-5e-7),axis=0)
Z2 = z[mymin]


#Xp=X[(abs(w-5e-7)<1.e-7)]
#Yp=Y[(abs(w-5e-7)<1.e-7)]
#Zp=Z[(abs(w-5e-7)<1.e-7)]

xp2=np.zeros(100000)
yp2=np.zeros(100000)
zp2=np.zeros(100000)
counter=0
for i in range(41):
    for j in range(41):
        for k in range(41):
            if (abs(w[i,j,k]-5e-7)<3e-7 and z[i]<130):
                xp2[counter]=x[k]
                yp2[counter]=y[j]
                zp2[counter]=z[i]
                counter += 1
xp2=xp2[:counter]
yp2=yp2[:counter]
zp2=zp2[:counter]

xp3=np.zeros(100000)
yp3=np.zeros(100000)
zp3=np.zeros(100000)
counter=0
for i in range(41):
    for j in range(41):
        for k in range(0,40):
            if (abs(w[i,j,k]-5e-7)<3e-7 and z[i]>120 and not (x[k]<-24000 and x[k]>-26000 and y[j]<10.5 and y[j]>8.5 and z[i]>215)):
                xp3[counter]=x[k]
                yp3[counter]=y[j]
                zp3[counter]=z[i]
                counter += 1
xp3=xp3[:counter]
yp3=yp3[:counter]
zp3=zp3[:counter]

#distance=np.zeros([counter,counter]) + 1e10
#for i in range(counter):
#    for j in range(counter):
#        if (i!=j):
#            distance[i,j]=np.sqrt( np.power(xp3[i]-xp3[j],2) + np.power(yp3[i]-yp3[j],2) + np.power(zp3[i]-zp3[j],2))

# %%
#print(np.amin(distance,axis=0))

#plt.plot(np.amin(distance,axis=0))

#sorteddist=np.sort(distance,axis=0)

#print(sorteddist[:2,:])

#plt.show()
# Out:
# [ 0.2625    0.2625    0.2625   ...,  2.45      6.25      6.713047]
# [[  0.2625       0.2625       0.2625     ...,   2.45         6.25
#     6.713047  ]
#  [  6.25061247   6.25061247   6.26529379 ...,   6.25         6.713047
#    12.50030625]]

# %%
# %matplotlib inline
#%matplotlib notebook

fig = plt.figure(figsize=(20,20))

ax = fig.gca(projection='3d')

ax.plot_trisurf(xp2,yp2,zp2,color='orange',alpha=0.5) #cmap=cm_fessa,)
ax.plot_trisurf(xp3,yp3,zp3,color='orange',alpha=0.5) #cmap=cm_fessa)
#ax.plot_surface(X,Y,Z1,cmap=cm_fessa,alpha=0.1)
#ax.plot_surface(X,Y,Z2,cmap=cm_fessa,alpha=0.1)

#from PIL import Image

#im = Image.open('/home/piaggp/Desktop/mi_clepsidra.png')
#height = im.size[1]

# We need a float array between 0-1, rather than
# a uint8 array between 0-255
#im = np.array(im).astype(np.float) / 255
#fig.figimage(im, 0, fig.bbox.ymax - height)

from matplotlib.cbook import get_sample_data

im = plt.imread(get_sample_data('/home/piaggp/Desktop/mi_clepsidra_2.png'))

#fig, ax = plt.subplots()
#ax.plot(range(10))

# Place the image in the upper-right corner of the figure
#--------------------------------------------------------
# We're specifying the position and size in _figure_ coordinates, so the image
# will shrink/grow as the figure is resized. Remove "zorder=-1" to place the
# image in front of the axes.
newax = fig.add_axes([0.23, 0.21, 0.6, 0.6], anchor='SW', zorder=10)
newax.imshow(im)
newax.axis('off')
           
ax.view_init(15, 135)

ax.set_xlim([-26500,-23500])
ax.set_ylim([8,11.5])
ax.set_zlim([0,250])
                             
plt.show()
